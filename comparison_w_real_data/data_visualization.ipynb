# %%
# Datasets
from tensorflow import keras
from matplotlib import pyplot

# load dataset
(train_images_1, train_labels_1), (test_images_1, test_labels_1) = keras.datasets.mnist.load_data()
(train_images_2, train_labels_2), (test_images_2, test_labels_2) = keras.datasets.cifar10.load_data()

# %%
train_img = train_images_1
train_label = train_labels_1

fig = plt.figure(figsize=(3, 3))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1, xticks=[], yticks=[])
    ax.imshow(train_img[i], cmap=plt.cm.binary, interpolation='nearest')

    # # label the image with the target value
    # ax.text(0, 7, str(train_label[i]))

fig.savefig(f'image/MNIST.jpg')

# %%
train_img = train_images_2
train_label = train_labels_2

fig = plt.figure(figsize=(3, 3))  # figure size in inches
# fig.suptitle(dataset.name)
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1, xticks=[], yticks=[])
    ax.imshow(train_img[i], cmap=plt.cm.binary, interpolation='nearest')
    
    # label the image with the target value
    # ax.text(0, 7, str(train_label[i]))

fig.savefig(f'image/CIFAR10.jpg')
